# %%
#aqui se importa el sqlite
import sqlite3
#aqui es donde se importa el pandas para realizar la lectura
import pandas as pd
#aqui es donde se importa la base de datos file 3 desde el sqlite
con = sqlite3.connect("file3.db")
#aqui es donde se lee el archivo para ver si funciona la importacion
file3 = pd.read_sql_query("SELECT * FROM file3", con)
file3
# Out:
#                        field1                    field2  \
# 0                         _id                      Tipo
# 1    6581ffbe7d4586d80596ad81        Habitación privada
# 2    6581ffbe7d4586d80596ad82        Habitación privada
# 3    6581ffbe7d4586d80596ad83  Alojamiento entero: piso
# 4    6581ffbe7d4586d80596ad84        Habitación privada
# ..                        ...                       ...
# 100  6581ffbe7d4586d80596ade4        Habitación privada
# 101  6581ffbe7d4586d80596ade5        Habitación privada
# 102  6581ffbe7d4586d80596ade6  Alojamiento entero: piso
# 103  6581ffbe7d4586d80596ade7        Habitación privada
# 104  6581ffbe7d4586d80596ade8        Habitación privada
#
#                                                 field3  \
# 0                                    nombreAlojamiento
# 1           Beautiful and sunny apartment at Eixample!
# 2                                 Room near the center
# 3      Luminoso y coqueto ático. - License HUTB-016889
# ...

# %%
#aqui es donde se debe importar el file2 desde mysql 
#lo hice exportando la base datos sql desde phpmyadmin exportando ese dataset a csv copiandolo dentro del jupyter para evitar fallas de lectura 
#y leyendolo con el pandas
import pandas as pd
file2=pd.read_csv("table_name.csv")
file2
# Out:
#                           _id                      Tipo  \
# 0    6581ffbe7d4586d80596acba        Habitación privada
# 1    6581ffbe7d4586d80596acbb  Alojamiento entero: loft
# 2    6581ffbe7d4586d80596acbc        Habitación privada
# 3    6581ffbe7d4586d80596acbd        Habitación privada
# 4    6581ffbe7d4586d80596acbe        Habitación privada
# ..                        ...                       ...
# 194  6581ffbe7d4586d80596ad7c        Habitación privada
# 195  6581ffbe7d4586d80596ad7d       Habitación de hotel
# 196  6581ffbe7d4586d80596ad7e        Habitación privada
# 197  6581ffbe7d4586d80596ad7f        Habitación privada
# 198  6581ffbe7d4586d80596ad80  Alojamiento entero: piso
#
#                                      nombreAlojamiento  \
# 0            Gran Habitación en el Centro de Barcelona
# 1                  Un espacio con encanto en Barcelona
# 2               Twin Room Central + Close to the beach
# 3       Habitación acogedora en el Centro de Barcelona
# ...

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
# Conexión al servidor de MongoDB
client = MongoClient('localhost:27017')
# Selección de la base de datos y la colección
db = client.file1
collection = db.file1
# Conversión de los datos de la colección a un DataFrame de pandas
file1 = pd.DataFrame(list(collection.find()))
#Lectrura de la base
file1
# Out:
#                           _id                          Tipo  \
# 0    6581ffbe7d4586d80596abf3      Alojamiento entero: piso
# 1    6581ffbe7d4586d80596abf4  Habitación de hotel boutique
# 2    6581ffbe7d4586d80596abf5            Habitación privada
# 3    6581ffbe7d4586d80596abf6            Habitación privada
# 4    6581ffbe7d4586d80596abf7      Alojamiento entero: piso
# ..                        ...                           ...
# 194  6581ffbe7d4586d80596acb5      Alojamiento entero: piso
# 195  6581ffbe7d4586d80596acb6            Habitación privada
# 196  6581ffbe7d4586d80596acb7            Habitación privada
# 197  6581ffbe7d4586d80596acb8            Habitación privada
# 198  6581ffbe7d4586d80596acb9            Habitación privada
#
#                                      nombreAlojamiento  \
# 0    Barcelona Marta´s Flat 2 - FC Barcelona HUTB01...
# 1     Habitación Doble Exterior, baño privado y balcón
# 2                  Luxury room with private bathroom 2
# ...

# %%
from pymongo import MongoClient
import pandas as pd

# Crea una conexión a MongoDB Atlas
client = MongoClient("mongodb+srv://ignnel01end:1234567890@ignn3l.umzbkt2.mongodb.net/")

# Selecciona tu base de datos y colección
db = client['file0']
collection = db['file0']

# Crea un DataFrame de pandas a partir de los datos de la colección
file0 = pd.DataFrame(list(collection.find()))
file0
# Out:
#                           _id                          Tipo  \
# 0    6581ffbe7d4586d80596ab2c            Habitación privada
# 1    6581ffbe7d4586d80596ab2d            Habitación privada
# 2    6581ffbe7d4586d80596ab2e            Habitación privada
# 3    6581ffbe7d4586d80596ab2f            Habitación privada
# 4    6581ffbe7d4586d80596ab30      Alojamiento entero: piso
# ..                        ...                           ...
# 194  6581ffbe7d4586d80596abee      Alojamiento entero: piso
# 195  6581ffbe7d4586d80596abef            Habitación privada
# 196  6581ffbe7d4586d80596abf0  Habitación de hotel boutique
# 197  6581ffbe7d4586d80596abf1           Habitación de hotel
# 198  6581ffbe7d4586d80596abf2            Habitación privada
#
#                                      nombreAlojamiento  \
# 0      Habitacion centro Barcelona, Ciutat Vella room.
# 1    Agradable habitación en pleno centro de Barcelona
# 2     Room in the city center (Gothic,Rambla,Catedral)
# ...

# %%
file3.to_csv('file3.csv', index=False)
b3 = pd.read_csv("file3.csv")
b3
# Out:
#                        field1                    field2  \
# 0                         _id                      Tipo
# 1    6581ffbe7d4586d80596ad81        Habitación privada
# 2    6581ffbe7d4586d80596ad82        Habitación privada
# 3    6581ffbe7d4586d80596ad83  Alojamiento entero: piso
# 4    6581ffbe7d4586d80596ad84        Habitación privada
# ..                        ...                       ...
# 100  6581ffbe7d4586d80596ade4        Habitación privada
# 101  6581ffbe7d4586d80596ade5        Habitación privada
# 102  6581ffbe7d4586d80596ade6  Alojamiento entero: piso
# 103  6581ffbe7d4586d80596ade7        Habitación privada
# 104  6581ffbe7d4586d80596ade8        Habitación privada
#
#                                                 field3  \
# 0                                    nombreAlojamiento
# 1           Beautiful and sunny apartment at Eixample!
# 2                                 Room near the center
# 3      Luminoso y coqueto ático. - License HUTB-016889
# ...

# %%
file2.to_csv('file2.csv', index=False)
b2 = pd.read_csv("file2.csv")
b2
# Out:
#                           _id                      Tipo  \
# 0    6581ffbe7d4586d80596acba        Habitación privada
# 1    6581ffbe7d4586d80596acbb  Alojamiento entero: loft
# 2    6581ffbe7d4586d80596acbc        Habitación privada
# 3    6581ffbe7d4586d80596acbd        Habitación privada
# 4    6581ffbe7d4586d80596acbe        Habitación privada
# ..                        ...                       ...
# 194  6581ffbe7d4586d80596ad7c        Habitación privada
# 195  6581ffbe7d4586d80596ad7d       Habitación de hotel
# 196  6581ffbe7d4586d80596ad7e        Habitación privada
# 197  6581ffbe7d4586d80596ad7f        Habitación privada
# 198  6581ffbe7d4586d80596ad80  Alojamiento entero: piso
#
#                                      nombreAlojamiento  \
# 0            Gran Habitación en el Centro de Barcelona
# 1                  Un espacio con encanto en Barcelona
# 2               Twin Room Central + Close to the beach
# 3       Habitación acogedora en el Centro de Barcelona
# ...

# %%
file1.to_csv('file1.csv', index=False)
b1 = pd.read_csv("file1.csv")
b1
# Out:
#                           _id                          Tipo  \
# 0    6581ffbe7d4586d80596abf3      Alojamiento entero: piso
# 1    6581ffbe7d4586d80596abf4  Habitación de hotel boutique
# 2    6581ffbe7d4586d80596abf5            Habitación privada
# 3    6581ffbe7d4586d80596abf6            Habitación privada
# 4    6581ffbe7d4586d80596abf7      Alojamiento entero: piso
# ..                        ...                           ...
# 194  6581ffbe7d4586d80596acb5      Alojamiento entero: piso
# 195  6581ffbe7d4586d80596acb6            Habitación privada
# 196  6581ffbe7d4586d80596acb7            Habitación privada
# 197  6581ffbe7d4586d80596acb8            Habitación privada
# 198  6581ffbe7d4586d80596acb9            Habitación privada
#
#                                      nombreAlojamiento  \
# 0    Barcelona Marta´s Flat 2 - FC Barcelona HUTB01...
# 1     Habitación Doble Exterior, baño privado y balcón
# 2                  Luxury room with private bathroom 2
# ...

# %%
file0.to_csv('file0.csv', index=False)
b0 = pd.read_csv("file0.csv")
b0
# Out:
#                           _id                          Tipo  \
# 0    6581ffbe7d4586d80596ab2c            Habitación privada
# 1    6581ffbe7d4586d80596ab2d            Habitación privada
# 2    6581ffbe7d4586d80596ab2e            Habitación privada
# 3    6581ffbe7d4586d80596ab2f            Habitación privada
# 4    6581ffbe7d4586d80596ab30      Alojamiento entero: piso
# ..                        ...                           ...
# 194  6581ffbe7d4586d80596abee      Alojamiento entero: piso
# 195  6581ffbe7d4586d80596abef            Habitación privada
# 196  6581ffbe7d4586d80596abf0  Habitación de hotel boutique
# 197  6581ffbe7d4586d80596abf1           Habitación de hotel
# 198  6581ffbe7d4586d80596abf2            Habitación privada
#
#                                      nombreAlojamiento  \
# 0      Habitacion centro Barcelona, Ciutat Vella room.
# 1    Agradable habitación en pleno centro de Barcelona
# 2     Room in the city center (Gothic,Rambla,Catedral)
# ...

# %%
lista = pd.concat([b3,b2,b1,b0])
lista
lista.to_csv('lista.csv')
lista= pd.read_csv("lista.csv")
lista
# Out:
#      Unnamed: 0                    field1                    field2  \
# 0             0                       _id                      Tipo
# 1             1  6581ffbe7d4586d80596ad81        Habitación privada
# 2             2  6581ffbe7d4586d80596ad82        Habitación privada
# 3             3  6581ffbe7d4586d80596ad83  Alojamiento entero: piso
# 4             4  6581ffbe7d4586d80596ad84        Habitación privada
# ..          ...                       ...                       ...
# 697         194                       NaN                       NaN
# 698         195                       NaN                       NaN
# 699         196                       NaN                       NaN
# 700         197                       NaN                       NaN
# 701         198                       NaN                       NaN
#
#                                               field3  \
# 0                                  nombreAlojamiento
# ...

# %%
# Importa las bibliotecas necesarias
import pandas as pd
from pymongo import MongoClient

# Carga el archivo CSV en un DataFrame de pandas
df = pd.read_csv('lista.csv')

# Conéctate a MongoDB Atlas
client = MongoClient("mongodb+srv://ignnel01end:1234567890@ignn3l.umzbkt2.mongodb.net/")

# Selecciona la base de datos y la colección
db = client.lista_unificada
collection = db.lista_general

# Convierte el DataFrame a un diccionario y carga los datos en la colección
data = df.to_dict("records")
collection.insert_many(data)
# Out:
# InsertManyResult(['6581ffbe7d4586d80596acba', '6581ffbe7d4586d80596acbb', '6581ffbe7d4586d80596acbc', '6581ffbe7d4586d80596acbd', '6581ffbe7d4586d80596acbe', '6581ffbe7d4586d80596acbf', '6581ffbe7d4586d80596acc0', '6581ffbe7d4586d80596acc1', '6581ffbe7d4586d80596acc2', '6581ffbe7d4586d80596acc3', '6581ffbe7d4586d80596acc4', '6581ffbe7d4586d80596acc5', '6581ffbe7d4586d80596acc6', '6581ffbe7d4586d80596acc7', '6581ffbe7d4586d80596acc8', '6581ffbe7d4586d80596acc9', '6581ffbe7d4586d80596acca', '6581ffbe7d4586d80596accb', '6581ffbe7d4586d80596accc', '6581ffbe7d4586d80596accd', '6581ffbe7d4586d80596acce', '6581ffbe7d4586d80596accf', '6581ffbe7d4586d80596acd0', '6581ffbe7d4586d80596acd1', '6581ffbe7d4586d80596acd2', '6581ffbe7d4586d80596acd3', '6581ffbe7d4586d80596acd4', '6581ffbe7d4586d80596acd5', '6581ffbe7d4586d80596acd6', '6581ffbe7d4586d80596acd7', '6581ffbe7d4586d80596acd8', '6581ffbe7d4586d80596acd9', '6581ffbe7d4586d80596acda', '6581ffbe7d4586d80596acdb', '6581ffbe7d4586d80596acdc', 
# ...

# %%
from pymongo import MongoClient
import pandas as pd

# Crea una conexión a MongoDB Atlas
client = MongoClient("mongodb+srv://ignnel01end:1234567890@ignn3l.umzbkt2.mongodb.net/")

# Selecciona tu base de datos y colección
db = client['lista_unificada']
collection = db['lista_general']

# Crea un DataFrame de pandas a partir de los datos de la colección
lista_unificada = pd.DataFrame(list(collection.find()))
lista_unificada
# Out:
#                           _id  Unnamed: 0                          Tipo  \
# 0    6581ffbe7d4586d80596acba           0            Habitación privada
# 1    6581ffbe7d4586d80596acbb           1      Alojamiento entero: loft
# 2    6581ffbe7d4586d80596acbc           2            Habitación privada
# 3    6581ffbe7d4586d80596acbd           3            Habitación privada
# 4    6581ffbe7d4586d80596acbe           4            Habitación privada
# ..                        ...         ...                           ...
# 592  6581ffbe7d4586d80596abee         194      Alojamiento entero: piso
# 593  6581ffbe7d4586d80596abef         195            Habitación privada
# 594  6581ffbe7d4586d80596abf0         196  Habitación de hotel boutique
# 595  6581ffbe7d4586d80596abf1         197           Habitación de hotel
# 596  6581ffbe7d4586d80596abf2         198            Habitación privada
#
#                                      nombreAlojamiento  \
# ...

# %%
#a. Verificar el tiempo que se demora en cargar el data set
from pymongo import MongoClient
import pandas as pd

# Crea una conexión a MongoDB Atlas
client = MongoClient("mongodb+srv://ignnel01end:1234567890@ignn3l.umzbkt2.mongodb.net/")

# Selecciona tu base de datos y colección
db = client['lista_unificada']
collection = db['lista_general']

# Crea un DataFrame de pandas a partir de los datos de la colección
lista_unificada = pd.DataFrame(list(collection.find()))
start = time.time()
end= time.time()
print("Tiempo de ejecución:", end_time - start_time, "segundos")
# Out:
# Tiempo de ejecución: 1.4344966411590576 segundos

# %%
#b. Verificar el número de registros.
lista_unificada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 597 entries, 0 to 596
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   _id                597 non-null    object
#  1   Unnamed: 0         597 non-null    int64
#  2   Tipo               597 non-null    object
#  3   nombreAlojamiento  597 non-null    object
#  4   Zona               597 non-null    object
#  5   Nhab               597 non-null    object
#  6   Servicios          597 non-null    object
#  7   Fechas             597 non-null    object
#  8   Valoracion         572 non-null    object
#  9   Evaluaciones       597 non-null    object
#  10  Noche              597 non-null    object
#  11  Total              597 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 56.1+ KB

# %%
#c. Verificar si hay registros duplicados, en el caso de haberlos, deberá eliminar los duplicados.
lista_unificada = lista_unificada.drop_duplicates()
temp_df.shape
# Out:
# (597, 12)

# %%
#d. Verificar si hay celdas nulas
lista_unificada.isnull()
# Out:
#        _id  Unnamed: 0   Tipo  nombreAlojamiento   Zona   Nhab  Servicios  \
# 0    False       False  False              False  False  False      False
# 1    False       False  False              False  False  False      False
# 2    False       False  False              False  False  False      False
# 3    False       False  False              False  False  False      False
# 4    False       False  False              False  False  False      False
# ..     ...         ...    ...                ...    ...    ...        ...
# 592  False       False  False              False  False  False      False
# 593  False       False  False              False  False  False      False
# 594  False       False  False              False  False  False      False
# 595  False       False  False              False  False  False      False
# 596  False       False  False              False  False  False      False
#
#      Fechas  Valoracion  Evaluaciones  Noche  Total
# ...

# %%
lista_unificada.isnull().sum()
# Out:
# _id                   0
# Unnamed: 0            0
# Tipo                  0
# nombreAlojamiento     0
# Zona                  0
# Nhab                  0
# Servicios             0
# Fechas                0
# Valoracion           25
# Evaluaciones          0
# Noche                 0
# Total                 0
# dtype: int64

# %%
#e. En caso de haber celdas nulas, se deberá sacar el promedio y completar la información con la media.
valoracion = lista_unificada['Valoracion']
valoracion
# Out:
# 0      4,75
# 1      4,81
# 2       4,5
# 3      4,31
# 4      4,86
#        ...
# 592    4,76
# 593     4,9
# 594     4,4
# 595    4,52
# 596    4,88
# Name: Valoracion, Length: 597, dtype: object

# %%
#El error que sale aqui se debe a que estamos intentando calcular la media de una columna que contiene valores no numéricos. 
#En Python, no puedes concatenar strings con enteros, lo que parece ser el problema aquí.
#por lo que toca transformalos a numeros y de ahi calculamos la media
lista_unificada['Valoracion'] = pd.to_numeric(lista_unificada['Valoracion'], errors='coerce')
valoracion_mean = lista_unificada['Valoracion'].mean()
valoracion_mean
# Out:
# 4.875

# %%
valoracion.fillna(valoracion_mean,inplace=True)
valoracion
# Out:
# 0      4,75
# 1      4,81
# 2       4,5
# 3      4,31
# 4      4,86
#        ...
# 592    4,76
# 593     4,9
# 594     4,4
# 595    4,52
# 596    4,88
# Name: Valoracion, Length: 597, dtype: object

# %%
lista_unificada.isnull().sum()
# Out:
# _id                  0
# Unnamed: 0           0
# Tipo                 0
# nombreAlojamiento    0
# Zona                 0
# Nhab                 0
# Servicios            0
# Fechas               0
# Valoracion           0
# Evaluaciones         0
# Noche                0
# Total                0
# dtype: int64

# %%
#f. Describir el data set
lista_unificada.describe()
# Out:
#        Unnamed: 0
# count  597.000000
# mean    99.000000
# std     57.493799
# min      0.000000
# 25%     49.000000
# 50%     99.000000
# 75%    149.000000
# max    198.000000

# %%
#g. Describir usando campos definidos, mostrando 10 filas.
lista_unificada['Zona'].value_counts().head(10)
# Out:
# Zona
# Ciutat Vella                            138
# Eixample                                112
# Sant Pere-Santa Caterina i la Ribera     42
# Gràcia                                   36
# L'Hospitalet de Llobregat                35
# La Sagrada Familia                       34
# Sant Marti                               28
# El Poble Sec                             28
# Distrito de Sants-Montjuïc               23
# El Fort Pienc                            19
# Name: count, dtype: int64

# %%
# h. Indica el alojamiento más costoso por noche
# Convierte la columna 'Noche' a tipo numérico (float) si aún no lo está
lista_unificada['Noche'] = pd.to_numeric(lista_unificada['Noche'], errors='coerce')

# Verifica y elimina los caracteres no deseados
if lista_unificada['Noche'].dtype == 'O':  # Comprueba si la columna es de tipo objeto (string)
    lista_unificada['Noche'] = pd.to_numeric(lista_unificada['Noche'].str.replace('€', '').str.replace(',', ''), errors='coerce')

noche_mas_alta = lista_unificada[lista_unificada['Noche'] == lista_unificada['Noche'].max()]
noche_mas_alta
# Out:
#                           _id  Unnamed: 0                      Tipo  \
# 169  6581ffbe7d4586d80596ad63         169  Alojamiento entero: piso
# 267  6581ffbe7d4586d80596ac37          68  Alojamiento entero: piso
#
#                   nombreAlojamiento          Zona  \
# 169  My Address in Plaza Real views  Ciutat Vella
# 267  My Address in Plaza Real views  Ciutat Vella
#
#                                                Nhab  \
# 169  4 huéspedes · 2 dormitorios · 4 camas · 1 baño
# 267  4 huéspedes · 2 dormitorios · 4 camas · 1 baño
#
#                                              Servicios             Fechas  \
# 169  Tu anfitrión es una empresa · Wifi · Aire acon...  10 dic. – 12 dic.
# 267  Tu anfitrión es una empresa · Wifi · Aire acon...  10 dic. – 12 dic.
#
#      Valoracion        Evaluaciones  Noche          Total
# 169         NaN   (38 evaluaciones)    175  350€ en total
# 267         NaN   (38 evaluaciones)    175  350€ en total

# %%
# Ahora puedes aplicar tus operaciones de string
#lista_unificada['Total'] = pd.to_numeric(lista_unificada['Total'].str.replace('€ en total', '').str.replace(',', ''), errors='coerce')

# Encuentra el total cancelado más alto
#total_mas_alto = lista_unificada[lista_unificada['Total'] == lista_unificada['Total'].max()]
#total_mas_alto

# %%
# j. Indica el tipo de alojamiento que hay para 6 personas
# Asegúrate de reemplazar 'nombre_columna' con el nombre de la columna que contiene el número de personas
#alojamiento_para_6 = lista_unificada[(lista_unificada['Nhab'] == '2 huèspedes')]
#alojamiento_para_6
# Out:
# Empty DataFrame
# Columns: [_id, Unnamed: 0, Tipo, nombreAlojamiento, Zona, Nhab, Servicios, Fechas, Valoracion, Evaluaciones, Noche, Total]
# Index: []

# %%
# k. Verifica cuál es la valoración más alta y cuál es la valoración más baja de los tipos de alojamientos
# Convierte la columna 'Valoracion' a tipo numérico (float)
lista_unificada['Valoracion'] = pd.to_numeric(lista_unificada['Valoracion'], errors='coerce')

# Verifica cuál es la valoración más alta y cuál es la valoración más baja
valoracion_mas_alta = lista_unificada[lista_unificada['Valoracion'] == lista_unificada['Valoracion'].max()]
valoracion_mas_alta
# Out:
#                           _id  Unnamed: 0                      Tipo  \
# 49   6581ffbe7d4586d80596aceb          49        Habitación privada
# 56   6581ffbe7d4586d80596acf2          56      Habitación de hostal
# 91   6581ffbe7d4586d80596ad15          91  Alojamiento entero: piso
# 158  6581ffbe7d4586d80596ad58         158      Habitación de hostal
# 163  6581ffbe7d4586d80596ad5d         163        Habitación privada
# 171  6581ffbe7d4586d80596ad65         171        Habitación privada
# 182  6581ffbe7d4586d80596ad70         182  Alojamiento entero: loft
# 189  6581ffbe7d4586d80596ad77         189        Habitación privada
# 256  6581ffbe7d4586d80596ac2c          57      Habitación de hostal
# 261  6581ffbe7d4586d80596ac31          62        Habitación privada
# 269  6581ffbe7d4586d80596ac39          70        Habitación privada
# 280  6581ffbe7d4586d80596ac44          81  Alojamiento entero: loft
# 287  6581ffbe7d4586d80596ac4b          88        Habitación privada
# ...

# %%
lista_unificada['Valoracion'] = pd.to_numeric(lista_unificada['Valoracion'], errors='coerce')
valoracion_mas_baja = lista_unificada[lista_unificada['Valoracion'] == lista_unificada['Valoracion'].min()]
valoracion_mas_baja
# Out:
#                           _id  Unnamed: 0                      Tipo  \
# 41   6581ffbe7d4586d80596ace3          41        Habitación privada
# 156  6581ffbe7d4586d80596ad56         156  Alojamiento entero: piso
# 254  6581ffbe7d4586d80596ac2a          55  Alojamiento entero: piso
# 537  6581ffbe7d4586d80596abb7         139        Habitación privada
#
#                                      nombreAlojamiento  \
# 41   SUNNY room for 2 or 3 person near sagrada familia
# 156                           OLA LIVING BORN 10 ATTIC
# 254                           OLA LIVING BORN 10 ATTIC
# 537  SUNNY room for 2 or 3 person near sagrada familia
#
#                                      Zona  \
# 41             Distrito de Horta-Guinardó
# 156  Sant Pere-Santa Caterina i la Ribera
# 254  Sant Pere-Santa Caterina i la Ribera
# 537            Distrito de Horta-Guinardó
#
#                                                   Nhab  \
# 41   3 huéspedes · 1 dormitorio · 2 camas · 1 baño ...
# ...

# %%
#11. Exportar a MySQL el archivo unificado.
#12. Además, exporte el archivo unificado con extensión .txt.
