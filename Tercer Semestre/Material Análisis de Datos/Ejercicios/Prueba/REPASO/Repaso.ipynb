# %%
#1
#Exportar con la extensión que crea conveniente SQLITE
#transformar el archivo a csv
import sqlite3
import pandas as pd
# Conectar a la base de datos
conexion = sqlite3.connect('file3.db')
# Utilizar Pandas para leer datos desde file3
dataframe = pd.read_sql_query('SELECT * FROM file3', conexion)
dataframe2 = pd.read_sql_query('SELECT * FROM file2', conexion)
dataframe3 = pd.read_sql_query('SELECT * FROM TABLE_NAME', conexion)
# Exportar el DataFrame a un archivo CSV llamado 'file3.csv'
#usar concat para unir los 3 dataframes
dataframesql =  pd.concat([dataframe3,dataframe2,dataframe])
dataframesql.to_csv('file3.csv', index=False)
print(dataframesql)
# cerrar la conexión 
conexion.close()

# %%
#2
import mysql.connector
import pandas as pd
# Conectar a la base de datos MySQL
con = mysql.connector.connect(
    host='DESKTOP-8LTE1A4',  # O proporciona la dirección IP del servidor MySQL #ipconfig ipv4
    port=3306,         # Puerto por defecto para MySQL
    user='root',
    password='123456mm',
    database='Hotel'
)
# Leer datos de la tabla PRODUCTOS en un DataFrame
dataframemysql = pd.read_sql_query("SELECT * FROM table_name", con)
print(dataframemysql)

# %%
#3
#importar libreria de py mongo y mongoclient
import pymongo
from pymongo import MongoClient
#conexion
conexion=MongoClient("localhost",27017)
#basez
base = conexion.test
#coleccion
coleccion = base.test
#crear dataframe
dataframemongo = pd.DataFrame(list(coleccion.find()))
print(dataframemongo)
#fin de conexion
conexion.close()

# %%
#4
from pymongo import MongoClient
import pandas as pd

client = MongoClient("mongodb+srv://Wesitos:123456XD@khaos-server.zbfgbzm.mongodb.net/")

# Selecciona tu base de datos y colección
db = client['file0']
collection = db['file0']

# Crea un DataFrame de pandas a partir de los datos de la colección
dataframemongoatlas = pd.DataFrame(list(collection.find()))
print(dataframemongoatlas)
client.close()

# %%
dataframemongoatlas

# %%
dataframemongo

# %%
dataframemysql

# %%
dataframesql

# %%
dataframetotal= pd.concat([dataframesql,dataframemysql,dataframemongo,dataframemongoatlas])

# %%
#unifico en csv para despues subir el dataframe por mongo compass
dataframetotal.to_csv('dataframetotal.csv', index=False)

# %%
from pymongo import MongoClient
import pandas as pd

client = MongoClient("mongodb+srv://Wesitos:123456XD@khaos-server.zbfgbzm.mongodb.net/")

# Selecciona tu base de datos y colección
db = client['DatosUnificados']
collection = db['Union']

# Crea un DataFrame de pandas a partir de los datos de la colección
dataframefinal = pd.DataFrame(list(collection.find()))
print(dataframefinal)
client.close()

# %%
#verificar tiempo que se demora en cargar data set
import time
inicio = time.time()
print(dataframefinal)
round(time.time()-inicio,5)

# %%
#verificar el  numero de registros
dataframefinal[['_id']].size

# %%
#registros duplicados
duplicados = dataframefinal[dataframefinal.duplicated()]
if not duplicados.empty:
    print("Registros duplicados encontrados. Eliminando duplicados...")
    df = df.drop_duplicates()
    print("Duplicados eliminados.")
else:
    print("No se encontraron registros duplicados.")
print(duplicados.info())

# %%
celdas_nulas = dataframefinal.isnull().sum()
if not celdas_nulas.empty:
    print("El DataFrame tiene celdas nulas.")
    print("Detalles sobre celdas nulas:")
    print(celdas_nulas)
    promedio = np.mean(celdas_nulas)
    print("Promedio de celdas nulas por columna:", promedio)
else:
    print("El DataFrame no tiene celdas nulas.")

# %%
dataframefinal['Valoracion'] = pd.to_numeric(dataframefinal['Valoracion'], errors='coerce')
promedio = dataframefinal['Valoracion'].mean()
promedio
# Out:
# 4.885714285714286

# %%
#remplazar valores
remplazo = dataframefinal['Valoracion']
remplazo.fillna(promedio,inplace=True)
remplazo
# Out:
# 0      4.885714
# 1      4.885714
# 2      4.885714
# 3      4.885714
# 4      4.885714
#          ...
# 697    4.885714
# 698    4.885714
# 699    4.885714
# 700    4.885714
# 701    4.885714
# Name: Valoracion, Length: 702, dtype: float64

# %%
# Describir el data set
dataframefinal_description = dataframefinal.describe()
print(dataframefinal_description)

# %%
dataframefinal.describe()
# Out:
#        Valoracion
# count  702.000000
# mean     4.885714
# std      0.071092
# min      4.000000
# 25%      4.885714
# 50%      4.885714
# 75%      4.885714
# max      5.000000

# %%
# Mostrar 10 filas del data set
dataframefinal['nombreAlojamiento'].value_counts().head(10)
# Out:
# nombreAlojamiento
# Habitación doble en Sagrada Familia                   5
# Single room in the heart of Gracia                    4
# Charming private 1 bedroom w/ balcony in Poble Sec    3
# SINGLE private bedroom                                3
# Room with big bed                                     3
# Beach modern spacious room Queen bed in Poblenou      3
# Quietpen PReïal. Rooftop                              3
# Habitación Doble con baño privado externo- 1 cama     3
# Room Sagrada Familia + Rooftop                        3
# Habitación doble Barcelona Centro                     3
# Name: count, dtype: int64

# %%
#indique el alojamiento mas costoso por noche

# %%
dataframefinal['Noche'].head(1)
# Out:
# 0    58 €
# Name: Noche, dtype: object

# %%
dataframefinal['Total'].head(1)
# Out:
# 0    116€ en total
# Name: Total, dtype: object

# %%
dataframefinal['Tipo'].value_counts().head(10)
# Out:
# Tipo
# Habitación privada                             442
# Alojamiento entero: piso                       138
# Alojamiento entero: loft                        27
# Habitación de hostal                            23
# Habitación de hotel boutique                    22
# Apartamento con servicios entero                19
# Habitación de hotel                             18
# Alojamiento entero: apartamento                  8
# Habitación                                       2
# Alojamiento entero: alojamiento residencial      2
# Name: count, dtype: int64

# %%
valoracionalta = dataframefinal[dataframefinal['Valoracion'] == dataframefinal['Valoracion'].max()]
valoracionalta
# Out:
#                           _id                      Tipo  \
# 29   6581ffbe7d4586d80596ad9e  Alojamiento entero: piso
# 52   6581ffbe7d4586d80596adb5  Alojamiento entero: piso
# 80   6581ffbe7d4586d80596add1        Habitación privada
# 154  6581ffbe7d4586d80596aceb        Habitación privada
# 161  6581ffbe7d4586d80596acf2      Habitación de hostal
# 196  6581ffbe7d4586d80596ad15  Alojamiento entero: piso
# 263  6581ffbe7d4586d80596ad58      Habitación de hostal
# 268  6581ffbe7d4586d80596ad5d        Habitación privada
# 276  6581ffbe7d4586d80596ad65        Habitación privada
# 287  6581ffbe7d4586d80596ad70  Alojamiento entero: loft
# 294  6581ffbe7d4586d80596ad77        Habitación privada
# 361  6581ffbe7d4586d80596ac2c      Habitación de hostal
# 366  6581ffbe7d4586d80596ac31        Habitación privada
# 374  6581ffbe7d4586d80596ac39        Habitación privada
# 385  6581ffbe7d4586d80596ac44  Alojamiento entero: loft
# 392  6581ffbe7d4586d80596ac4b        Habitación privada
# ...

# %%
valoracionbaja = dataframefinal[dataframefinal['Valoracion'] == dataframefinal['Valoracion'].min()]
valoracionbaja
# Out:
#                           _id                      Tipo  \
# 146  6581ffbe7d4586d80596ace3        Habitación privada
# 261  6581ffbe7d4586d80596ad56  Alojamiento entero: piso
# 359  6581ffbe7d4586d80596ac2a  Alojamiento entero: piso
# 642  6581ffbe7d4586d80596abb7        Habitación privada
#
#                                      nombreAlojamiento  \
# 146  SUNNY room for 2 or 3 person near sagrada familia
# 261                           OLA LIVING BORN 10 ATTIC
# 359                           OLA LIVING BORN 10 ATTIC
# 642  SUNNY room for 2 or 3 person near sagrada familia
#
#                                      Zona  \
# 146            Distrito de Horta-Guinardó
# 261  Sant Pere-Santa Caterina i la Ribera
# 359  Sant Pere-Santa Caterina i la Ribera
# 642            Distrito de Horta-Guinardó
#
#                                                   Nhab  \
# 146  3 huéspedes · 1 dormitorio · 2 camas · 1 baño ...
# 261            2 huéspedes · Estudio · 1 cama · 1 baño
# ...

# %%
#11.	Exportar a MySQL el archivo unificado.
import pandas as pd
from sqlalchemy import create_engine #necesario para exportar a mysql pip install sqlalchemy
final_csv = 'final.csv'
# Con
usuario = 'root'
contrasena = '123456'
host = 'localhost'
puerto = '3306'
nombre_bd = 'final'

df = pd.read_csv(final_csv)
#conexión a la base de datos mysql con sqlalchemy
engine = create_engine(f'mysql+mysqlconnector://{usuario}:{contrasena}@{host}:{puerto}/{nombre_bd}')

nombre_tabla = 'tabla_final'

# Exportar el df a mysql
df.to_sql(name=nombre_tabla, con=engine, if_exists='replace', index=False)

print(f'Datos exportados a la tabla {nombre_tabla} en MySQL.')

# %%
#12.	Además, exporte el archivo unificado con extensión .txt.
archivo_csv = 'final.csv'
df = pd.read_csv(archivo_csv)

# Especificar el nombre del archivo de texto de salida
archivo_txt = 'final.txt'

# Escribir los datos en el archivo de texto
df.to_csv(archivo_txt, sep='\t', index=False, header=None)
